# %%
# Import necessary libraries and modules for text preprocessing, analysis, and visualization
import warnings
warnings.filterwarnings('ignore')

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style as style
import nltk
import statsmodels.api as sm
import statsmodels.tsa.api as smt

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Activation
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *

from sklearn import preprocessing, metrics
from sklearn.preprocessing import MinMaxScaler

import datetime as dt
from datetime import datetime

# %matplotlib inline

# %%
# Import data files from repository
apple = pd.read_csv('/content/drive/MyDrive/Project UCD/Combined Data/aapl_combined.csv')
google = pd.read_csv('/content/drive/MyDrive/Project UCD/Combined Data/goog_combined.csv')
microsoft = pd.read_csv('/content/drive/MyDrive/Project UCD/Combined Data/msft_combined.csv')
nvidia = pd.read_csv('/content/drive/MyDrive/Project UCD/Combined Data/nvda_combined.csv')
tesla = pd.read_csv('/content/drive/MyDrive/Project UCD/Combined Data/tsla_combined.csv')

# %%
# setting figure size
plt.figure(figsize=(6,25))

# Plotting the adj_close price and a 30-day rolling mean of adj_close price
# Apple
plt.subplot(5,1,1)
plt.plot(apple[['adj_close']])
plt.plot(apple.rolling(window=5).mean()['adj_close'])
# Google
plt.subplot(5,1,2)
plt.plot(google[['adj_close']])
plt.plot(google.rolling(window=5).mean()['adj_close'])
# Microsoft
plt.subplot(5,1,3)
plt.plot(microsoft[['adj_close']])
plt.plot(microsoft.rolling(window=5).mean()['adj_close'])
# Nvidia
plt.subplot(5,1,4)
plt.plot(nvidia[['adj_close']])
plt.plot(nvidia.rolling(window=5).mean()['adj_close'])
# Tesla
plt.subplot(5,1,5)
plt.plot(tesla[['adj_close']])
plt.plot(tesla.rolling(window=5).mean()['adj_close'])

# %%
# Convert 'date' column to datetime format
apple['date'] = pd.to_datetime(apple['date'])
google['date'] = pd.to_datetime(google['date'])
microsoft['date'] = pd.to_datetime(microsoft['date'])
nvidia['date'] = pd.to_datetime(nvidia['date'])
tesla['date'] = pd.to_datetime(tesla['date'])

# Filter data for test period (01-06-2023 to 01-07-2023)
test_start_date = pd.Timestamp('2023-06-10')
test_end_date = pd.Timestamp('2023-07-01')

test_data_aapl = apple[(apple['date'] >= test_start_date) & (apple['date'] <= test_end_date)]
test_data_goog = google[(google['date'] >= test_start_date) & (google['date'] <= test_end_date)]
test_data_msft = microsoft[(microsoft['date'] >= test_start_date) & (microsoft['date'] <= test_end_date)]
test_data_nvda = nvidia[(nvidia['date'] >= test_start_date) & (nvidia['date'] <= test_end_date)]
test_data_tsla = tesla[(tesla['date'] >= test_start_date) & (tesla['date'] <= test_end_date)]

# %%
# Filter data for training period
train_data_aapl = apple[apple['date'] < test_start_date]
train_data_goog = google[google['date'] < test_start_date]
train_data_msft = microsoft[microsoft['date'] < test_start_date]
train_data_nvda = nvidia[nvidia['date'] < test_start_date]
train_data_tsla = tesla[tesla['date'] < test_start_date]

# Display the sizes of training and test sets
print("Training Data Size:", len(train_data_aapl))
print("Training Data Size:", len(train_data_goog))
print("Training Data Size:", len(train_data_msft))
print("Training Data Size:", len(train_data_nvda))
print("Training Data Size:", len(train_data_tsla))
print("Test Data Size:", len(test_data_aapl))
print("Test Data Size:", len(test_data_goog))
print("Test Data Size:", len(test_data_msft))
print("Test Data Size:", len(test_data_nvda))
print("Test Data Size:", len(test_data_tsla))
# Out:
# Training Data Size: 101
# Training Data Size: 101
# Training Data Size: 101
# Training Data Size: 101
# Training Data Size: 101
# Test Data Size: 22
# Test Data Size: 22
# Test Data Size: 22
# Test Data Size: 22
# Test Data Size: 22

# %%
# setting the target variable as the shifted close_price
y_aapl = apple['adj_close']
y_goog = google['adj_close']
y_msft = microsoft['adj_close']
y_nvda = nvidia['adj_close']
y_tsla = tesla['adj_close']

# %%
# setting the features dataset for prediction without sentiment scores
cols = ['open',  'volume', 'high', 'low']
x_aapl = apple[cols]
x_goog = google[cols]
x_msft = microsoft[cols]
x_nvda = nvidia[cols]
x_tsla = tesla[cols]

# %%
# scaling the feature dataset
scaler_x_aapl = preprocessing.MinMaxScaler(feature_range=(-1, 1))
x_aapl = np.array(x_aapl).reshape((len(x_aapl),len(cols)))
x_aapl = scaler_x_aapl.fit_transform(x_aapl)

scaler_x_goog = preprocessing.MinMaxScaler(feature_range=(-1, 1))
x_goog = np.array(x_goog).reshape((len(x_goog),len(cols)))
x_goog = scaler_x_goog.fit_transform(x_goog)

scaler_x_msft = preprocessing.MinMaxScaler(feature_range=(-1, 1))
x_msft = np.array(x_msft).reshape((len(x_msft),len(cols)))
x_msft = scaler_x_msft.fit_transform(x_msft)

scaler_x_nvda = preprocessing.MinMaxScaler(feature_range=(-1, 1))
x_nvda = np.array(x_nvda).reshape((len(x_nvda),len(cols)))
x_nvda = scaler_x_nvda.fit_transform(x_nvda)

scaler_x_tsla = preprocessing.MinMaxScaler(feature_range=(-1, 1))
x_tsla = np.array(x_tsla).reshape((len(x_tsla),len(cols)))
x_tsla = scaler_x_tsla.fit_transform(x_tsla)

# %%
# scaling the target variable
scaler_y_aapl = preprocessing.MinMaxScaler(feature_range=(-1, 1))
y_aapl = np.array(y_aapl).reshape((len(y_aapl), 1))
y_aapl = scaler_y_aapl.fit_transform(y_aapl)

scaler_y_goog = preprocessing.MinMaxScaler(feature_range=(-1, 1))
y_goog = np.array(y_goog).reshape((len(y_goog), 1))
y_goog = scaler_y_goog.fit_transform(y_goog)

scaler_y_msft = preprocessing.MinMaxScaler(feature_range=(-1, 1))
y_msft = np.array(y_msft).reshape((len(y_msft), 1))
y_msft = scaler_y_msft.fit_transform(y_msft)

scaler_y_nvda = preprocessing.MinMaxScaler(feature_range=(-1, 1))
y_nvda = np.array(y_nvda).reshape((len(y_nvda), 1))
y_nvda = scaler_y_nvda.fit_transform(y_nvda)

scaler_y_tsla = preprocessing.MinMaxScaler(feature_range=(-1, 1))
y_tsla = np.array(y_tsla).reshape((len(y_tsla), 1))
y_tsla = scaler_y_tsla.fit_transform(y_tsla)

# %%
train_size = 101
# preparing training and test dataset
X_train_aapl = x_aapl[0 : train_size,]
X_train_goog = x_goog[0 : train_size,]
X_train_msft = x_msft[0 : train_size,]
X_train_nvda = x_nvda[0 : train_size,]
X_train_tsla = x_tsla[0 : train_size,]

X_test_aapl = x_aapl[train_size : len(x_aapl),]
X_test_goog = x_goog[train_size : len(x_goog),]
X_test_msft = x_msft[train_size : len(x_msft),]
X_test_nvda = x_nvda[train_size : len(x_nvda),]
X_test_tsla = x_tsla[train_size : len(x_tsla),]

y_train_aapl = y_aapl[0 : train_size]
y_train_goog = y_goog[0 : train_size]
y_train_msft = y_msft[0 : train_size]
y_train_nvda = y_nvda[0 : train_size]
y_train_tsla = y_tsla[0 : train_size]

y_test_aapl = y_aapl[train_size : len(y_aapl)]
y_test_goog = y_goog[train_size : len(y_goog)]
y_test_msft = y_msft[train_size : len(y_msft)]
y_test_nvda = y_nvda[train_size : len(y_nvda)]
y_test_tsla = y_tsla[train_size : len(y_tsla)]

# %%
# reshaping the feature dataset for feeding into the model
X_train_aapl = X_train_aapl.reshape (X_train_aapl.shape + (1,))
X_train_goog = X_train_goog.reshape (X_train_goog.shape + (1,))
X_train_msft = X_train_msft.reshape (X_train_msft.shape + (1,))
X_train_nvda = X_train_nvda.reshape (X_train_nvda.shape + (1,))
X_train_tsla = X_train_tsla.reshape (X_train_tsla.shape + (1,))

X_test_aapl = X_test_aapl.reshape(X_test_aapl.shape + (1,))
X_test_goog = X_test_goog.reshape(X_test_goog.shape + (1,))
X_test_msft = X_test_msft.reshape(X_test_msft.shape + (1,))
X_test_nvda = X_test_nvda.reshape(X_test_nvda.shape + (1,))
X_test_tsla = X_test_tsla.reshape(X_test_tsla.shape + (1,))

# printing the re-shaped feature dataset
print(X_train_aapl.shape , y_train_aapl.shape)
print(X_test_aapl.shape , y_test_aapl.shape)
print(X_train_goog.shape , y_train_goog.shape)
print(X_test_goog.shape , y_test_goog.shape)
print(X_train_msft.shape , y_train_msft.shape)
print(X_test_msft.shape , y_test_msft.shape)
print(X_train_nvda.shape , y_train_nvda.shape)
print(X_test_nvda.shape , y_test_nvda.shape)
print(X_train_tsla.shape , y_train_tsla.shape)
print(X_test_tsla.shape , y_test_tsla.shape)
# Out:
# (101, 4, 1) (101, 1)
# (22, 4, 1) (22, 1)
# (101, 4, 1) (101, 1)
# (22, 4, 1) (22, 1)
# (101, 4, 1) (101, 1)
# (22, 4, 1) (22, 1)
# (101, 4, 1) (101, 1)
# (22, 4, 1) (22, 1)
# (101, 4, 1) (101, 1)
# (22, 4, 1) (22, 1)

# %%
# setting the seed to achieve consistent and less random predictions at each execution
np.random.seed(123)

# setting the model architecture
# Initializing the Neural Network based on LSTM
model = Sequential()
# Adding 1st LSTM layer
model.add(LSTM(units=64, return_sequences=False, input_shape=(len(cols), 1)))
# Adding 2nd LSTM layer
#model.add(LSTM(units=10, return_sequences=False, kernel_regularizer=l2(0.1)))
# Adding Dropout
model.add(Dropout(0.25))
# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# fitting the model using the training dataset
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=15, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
tb = TensorBoard('logs')

# printing the model summary
model.summary()

# fit the model
history_aapl = model.fit(X_train_aapl, y_train_aapl, shuffle=False, epochs=60,
                         callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 1/1 [==============================] - ETA: 0s - loss: 0.2214
# Epoch 1: val_loss improved from inf to 0.16308, saving model to weights.h5
# 1/1 [==============================] - 9s 9s/step - loss: 0.2214 - val_loss: 0.1631 - lr: 0.0100
# Epoch 2/60
# 1/1 [==============================] - ETA: 0s - loss: 0.1143
# Epoch 2: val_loss did not improve from 0.16308
# 1/1 [==============================] - 0s 161ms/step - loss: 0.1143 - val_loss: 0.2074 - lr: 0.0100
# Epoch 3/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0605
# Epoch 3: val_loss did not improve from 0.16308
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0605 - val_loss: 0.2477 - lr: 0.0100
# Epoch 4/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0696
# Epoch 4: val_loss did not improve from 0.16308
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0696 - val_loss: 0.2241 - lr: 0.0100
# Epoch 5/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0719
# Epoch 5: val_loss did not improve from 0.16308
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0719 - val_loss: 0.1718 - lr: 0.0100
# Epoch 6/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0521
# Epoch 6: val_loss improved from 0.16308 to 0.12221, saving model to weights.h5
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0521 - val_loss: 0.1222 - lr: 0.0100
# Epoch 7/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 7: val_loss improved from 0.12221 to 0.08421, saving model to weights.h5
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0374 - val_loss: 0.0842 - lr: 0.0100
# Epoch 8/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0358
# Epoch 8: val_loss improved from 0.08421 to 0.05829, saving model to weights.h5
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0358 - val_loss: 0.0583 - lr: 0.0100
# Epoch 9/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 9: val_loss improved from 0.05829 to 0.04260, saving model to weights.h5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0381 - val_loss: 0.0426 - lr: 0.0100
# Epoch 10/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0396
# Epoch 10: val_loss improved from 0.04260 to 0.03438, saving model to weights.h5
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0396 - val_loss: 0.0344 - lr: 0.0100
# Epoch 11/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0403
# Epoch 11: val_loss improved from 0.03438 to 0.03083, saving model to weights.h5
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0403 - val_loss: 0.0308 - lr: 0.0100
# Epoch 12/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0322
# Epoch 12: val_loss improved from 0.03083 to 0.03042, saving model to weights.h5
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0322 - val_loss: 0.0304 - lr: 0.0100
# Epoch 13/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 13: val_loss did not improve from 0.03042
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0225 - val_loss: 0.0313 - lr: 0.0100
# Epoch 14/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 14: val_loss did not improve from 0.03042
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0178 - val_loss: 0.0323 - lr: 0.0100
# Epoch 15/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0238
# Epoch 15: val_loss did not improve from 0.03042
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0238 - val_loss: 0.0307 - lr: 0.0100
# Epoch 16/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 16: val_loss improved from 0.03042 to 0.02577, saving model to weights.h5
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0287 - val_loss: 0.0258 - lr: 0.0100
# Epoch 17/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 17: val_loss improved from 0.02577 to 0.01978, saving model to weights.h5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0233 - val_loss: 0.0198 - lr: 0.0100
# Epoch 18/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 18: val_loss improved from 0.01978 to 0.01452, saving model to weights.h5
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0203 - val_loss: 0.0145 - lr: 0.0100
# Epoch 19/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 19: val_loss improved from 0.01452 to 0.01106, saving model to weights.h5
# 1/1 [==============================] - 0s 257ms/step - loss: 0.0155 - val_loss: 0.0111 - lr: 0.0100
# Epoch 20/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 20: val_loss improved from 0.01106 to 0.00933, saving model to weights.h5
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0198 - val_loss: 0.0093 - lr: 0.0100
# Epoch 21/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0229
# Epoch 21: val_loss improved from 0.00933 to 0.00892, saving model to weights.h5
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0229 - val_loss: 0.0089 - lr: 0.0100
# Epoch 22/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0241
# Epoch 22: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0241 - val_loss: 0.0096 - lr: 0.0100
# Epoch 23/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 23: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0207 - val_loss: 0.0114 - lr: 0.0100
# Epoch 24/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 24: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0128 - val_loss: 0.0140 - lr: 0.0100
# Epoch 25/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 25: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0148 - val_loss: 0.0173 - lr: 0.0100
# Epoch 26/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 26: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0176 - val_loss: 0.0204 - lr: 0.0100
# Epoch 27/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 27: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0176 - val_loss: 0.0221 - lr: 0.0100
# Epoch 28/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 28: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0147 - val_loss: 0.0227 - lr: 0.0100
# Epoch 29/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 29: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0138 - val_loss: 0.0226 - lr: 0.0100
# Epoch 30/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0139
# Epoch 30: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0139 - val_loss: 0.0220 - lr: 0.0100
# Epoch 31/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 31: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0111 - val_loss: 0.0215 - lr: 0.0100
# Epoch 32/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 32: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0122 - val_loss: 0.0212 - lr: 0.0100
# Epoch 33/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 33: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0114 - val_loss: 0.0213 - lr: 0.0100
# Epoch 34/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 34: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0152 - val_loss: 0.0217 - lr: 0.0100
# Epoch 35/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 35: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0098 - val_loss: 0.0222 - lr: 0.0100
# Epoch 36/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 36: val_loss did not improve from 0.00892
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0119 - val_loss: 0.0228 - lr: 0.0100
# Epoch 36: early stopping

# %%
# performing predictions
train_pred_aapl = model.predict(X_train_aapl)
# unscaling the predictions
train_pred_aapl = scaler_y_aapl.inverse_transform(np.array(train_pred_aapl).reshape((len(train_pred_aapl), 1)))
# printing the predictions
print('Train Predictions AAPL:')
train_pred_aapl[0:5]

# performing predictions
test_pred_aapl = model.predict(X_test_aapl)
# unscaling the predictions
test_pred_aapl = scaler_y_aapl.inverse_transform(np.array(test_pred_aapl).reshape((len(test_pred_aapl), 1)))
# printing the predictions
print('Test Predictions AAPL:')
test_pred_aapl[0:5]

# calculating the training mean-squared-error
train_loss_aapl = model.evaluate(X_train_aapl, y_train_aapl, batch_size = 1)
# calculating the test mean-squared-error
test_loss_aapl = model.evaluate(X_test_aapl, y_test_aapl, batch_size = 1)
# printing the training and the test mean-squared-errors
print('Train Loss AAPL=', round(train_loss_aapl,4))
print('Test Loss AAPL=', round(test_loss_aapl,4))
# Out:
# 4/4 [==============================] - 1s 9ms/step
# Train Predictions AAPL:
# 1/1 [==============================] - 0s 55ms/step
# Test Predictions AAPL:
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0117
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0918
# Train Loss AAPL= 0.0117
# Test Loss AAPL= 0.0918

# %%
# setting the seed to achieve consistent and less random predictions at each execution
np.random.seed(123)

# setting the model architecture
# Initializing the Neural Network based on LSTM
model = Sequential()
# Adding 1st LSTM layer
model.add(LSTM(units=64, return_sequences=False, input_shape=(len(cols), 1)))
# Adding 2nd LSTM layer
#model.add(LSTM(units=10, return_sequences=False, kernel_regularizer=l2(0.1)))
# Adding Dropout
model.add(Dropout(0.25))
# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# fitting the model using the training dataset
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=15, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
tb = TensorBoard('logs')

# printing the model summary
model.summary()

# fit the model
history_goog = model.fit(X_train_goog, y_train_goog, shuffle=False, epochs=60,
                         callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 1/1 [==============================] - ETA: 0s - loss: 0.2029
# Epoch 1: val_loss improved from inf to 0.63296, saving model to weights.h5
# 1/1 [==============================] - 7s 7s/step - loss: 0.2029 - val_loss: 0.6330 - lr: 0.0100
# Epoch 2/60
# 1/1 [==============================] - ETA: 0s - loss: 0.1090
# Epoch 2: val_loss improved from 0.63296 to 0.60649, saving model to weights.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1090 - val_loss: 0.6065 - lr: 0.0100
# Epoch 3/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0841
# Epoch 3: val_loss improved from 0.60649 to 0.50789, saving model to weights.h5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0841 - val_loss: 0.5079 - lr: 0.0100
# Epoch 4/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0835
# Epoch 4: val_loss improved from 0.50789 to 0.40028, saving model to weights.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0835 - val_loss: 0.4003 - lr: 0.0100
# Epoch 5/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0725
# Epoch 5: val_loss improved from 0.40028 to 0.31295, saving model to weights.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0725 - val_loss: 0.3129 - lr: 0.0100
# Epoch 6/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0491
# Epoch 6: val_loss improved from 0.31295 to 0.24206, saving model to weights.h5
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0491 - val_loss: 0.2421 - lr: 0.0100
# Epoch 7/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0348
# Epoch 7: val_loss improved from 0.24206 to 0.18226, saving model to weights.h5
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0348 - val_loss: 0.1823 - lr: 0.0100
# Epoch 8/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 8: val_loss improved from 0.18226 to 0.13300, saving model to weights.h5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0346 - val_loss: 0.1330 - lr: 0.0100
# Epoch 9/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 9: val_loss improved from 0.13300 to 0.09485, saving model to weights.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0366 - val_loss: 0.0949 - lr: 0.0100
# Epoch 10/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0348
# Epoch 10: val_loss improved from 0.09485 to 0.06652, saving model to weights.h5
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0348 - val_loss: 0.0665 - lr: 0.0100
# Epoch 11/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0235
# Epoch 11: val_loss improved from 0.06652 to 0.04578, saving model to weights.h5
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0235 - val_loss: 0.0458 - lr: 0.0100
# Epoch 12/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 12: val_loss improved from 0.04578 to 0.03166, saving model to weights.h5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0226 - val_loss: 0.0317 - lr: 0.0100
# Epoch 13/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 13: val_loss improved from 0.03166 to 0.02371, saving model to weights.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0249 - val_loss: 0.0237 - lr: 0.0100
# Epoch 14/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0277
# Epoch 14: val_loss improved from 0.02371 to 0.01983, saving model to weights.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0277 - val_loss: 0.0198 - lr: 0.0100
# Epoch 15/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 15: val_loss improved from 0.01983 to 0.01884, saving model to weights.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0280 - val_loss: 0.0188 - lr: 0.0100
# Epoch 16/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 16: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0210 - val_loss: 0.0199 - lr: 0.0100
# Epoch 17/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 17: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0207 - val_loss: 0.0229 - lr: 0.0100
# Epoch 18/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0228
# Epoch 18: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0228 - val_loss: 0.0273 - lr: 0.0100
# Epoch 19/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0228
# Epoch 19: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0228 - val_loss: 0.0325 - lr: 0.0100
# Epoch 20/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 20: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0183 - val_loss: 0.0382 - lr: 0.0100
# Epoch 21/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 21: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0144 - val_loss: 0.0440 - lr: 0.0100
# Epoch 22/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 22: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0144 - val_loss: 0.0501 - lr: 0.0100
# Epoch 23/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 23: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0157 - val_loss: 0.0554 - lr: 0.0100
# Epoch 24/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 24: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0156 - val_loss: 0.0599 - lr: 0.0100
# Epoch 25/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0146
# Epoch 25: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0146 - val_loss: 0.0631 - lr: 0.0100
# Epoch 26/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 26: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0134 - val_loss: 0.0648 - lr: 0.0100
# Epoch 27/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0139
# Epoch 27: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0139 - val_loss: 0.0649 - lr: 0.0100
# Epoch 28/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 28: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0128 - val_loss: 0.0630 - lr: 0.0100
# Epoch 29/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 29: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0123 - val_loss: 0.0594 - lr: 0.0100
# Epoch 30/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 30: val_loss did not improve from 0.01884
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0125 - val_loss: 0.0548 - lr: 0.0100
# Epoch 30: early stopping

# %%
# performing predictions
train_pred_goog = model.predict(X_train_goog)
# unscaling the predictions
train_pred_goog = scaler_y_goog.inverse_transform(np.array(train_pred_goog).reshape((len(train_pred_goog), 1)))
# printing the predictions
print('Train Predictions AAPL:')
train_pred_goog[0:5]

# performing predictions
test_pred_goog = model.predict(X_test_goog)
# unscaling the predictions
test_pred_goog = scaler_y_goog.inverse_transform(np.array(test_pred_goog).reshape((len(test_pred_goog), 1)))
# printing the predictions
print('Test Predictions GOOG:')
test_pred_goog[0:5]

# calculating the training mean-squared-error
train_loss_goog = model.evaluate(X_train_goog, y_train_goog, batch_size = 1)
# calculating the test mean-squared-error
test_loss_goog = model.evaluate(X_test_goog, y_test_goog, batch_size = 1)
# printing the training and the test mean-squared-errors
print('Train Loss GOOG=', round(train_loss_goog,4))
print('Test Loss GOOG=', round(test_loss_goog,4))
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Train Predictions AAPL:
# 1/1 [==============================] - 0s 22ms/step
# Test Predictions GOOG:
# 101/101 [==============================] - 0s 2ms/step - loss: 0.0188
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0396
# Train Loss GOOG= 0.0188
# Test Loss GOOG= 0.0396

# %%
# setting the seed to achieve consistent and less random predictions at each execution
np.random.seed(123)

# setting the model architecture
# Initializing the Neural Network based on LSTM
model = Sequential()
# Adding 1st LSTM layer
model.add(LSTM(units=64, return_sequences=False, input_shape=(len(cols), 1)))
# Adding 2nd LSTM layer
#model.add(LSTM(units=10, return_sequences=False, kernel_regularizer=l2(0.1)))
# Adding Dropout
model.add(Dropout(0.25))
# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# fitting the model using the training dataset
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=15, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
tb = TensorBoard('logs')

# printing the model summary
model.summary()

# fit the model
history_msft = model.fit(X_train_msft, y_train_msft, shuffle=False, epochs=60,
                         callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 64)                16896
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 1/1 [==============================] - ETA: 0s - loss: 0.2135
# Epoch 1: val_loss improved from inf to 0.41426, saving model to weights.h5
# 1/1 [==============================] - 4s 4s/step - loss: 0.2135 - val_loss: 0.4143 - lr: 0.0100
# Epoch 2/60
# 1/1 [==============================] - ETA: 0s - loss: 0.1218
# Epoch 2: val_loss did not improve from 0.41426
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1218 - val_loss: 0.4275 - lr: 0.0100
# Epoch 3/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0820
# Epoch 3: val_loss improved from 0.41426 to 0.41332, saving model to weights.h5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0820 - val_loss: 0.4133 - lr: 0.0100
# Epoch 4/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0835
# Epoch 4: val_loss improved from 0.41332 to 0.34517, saving model to weights.h5
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0835 - val_loss: 0.3452 - lr: 0.0100
# Epoch 5/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0725
# Epoch 5: val_loss improved from 0.34517 to 0.26834, saving model to weights.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0725 - val_loss: 0.2683 - lr: 0.0100
# Epoch 6/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0544
# Epoch 6: val_loss improved from 0.26834 to 0.20048, saving model to weights.h5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0544 - val_loss: 0.2005 - lr: 0.0100
# Epoch 7/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 7: val_loss improved from 0.20048 to 0.14521, saving model to weights.h5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0385 - val_loss: 0.1452 - lr: 0.0100
# Epoch 8/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 8: val_loss improved from 0.14521 to 0.10363, saving model to weights.h5
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0360 - val_loss: 0.1036 - lr: 0.0100
# Epoch 9/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 9: val_loss improved from 0.10363 to 0.07598, saving model to weights.h5
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0385 - val_loss: 0.0760 - lr: 0.0100
# Epoch 10/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0383
# Epoch 10: val_loss improved from 0.07598 to 0.05796, saving model to weights.h5
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0383 - val_loss: 0.0580 - lr: 0.0100
# Epoch 11/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 11: val_loss improved from 0.05796 to 0.04555, saving model to weights.h5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0285 - val_loss: 0.0456 - lr: 0.0100
# Epoch 12/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 12: val_loss improved from 0.04555 to 0.03716, saving model to weights.h5
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0273 - val_loss: 0.0372 - lr: 0.0100
# Epoch 13/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0304
# Epoch 13: val_loss improved from 0.03716 to 0.03215, saving model to weights.h5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0304 - val_loss: 0.0322 - lr: 0.0100
# Epoch 14/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 14: val_loss improved from 0.03215 to 0.02937, saving model to weights.h5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0276 - val_loss: 0.0294 - lr: 0.0100
# Epoch 15/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0242
# Epoch 15: val_loss improved from 0.02937 to 0.02901, saving model to weights.h5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0242 - val_loss: 0.0290 - lr: 0.0100
# Epoch 16/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 16: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0247 - val_loss: 0.0313 - lr: 0.0100
# Epoch 17/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0262
# Epoch 17: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0262 - val_loss: 0.0356 - lr: 0.0100
# Epoch 18/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0249
# Epoch 18: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0249 - val_loss: 0.0412 - lr: 0.0100
# Epoch 19/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0217
# Epoch 19: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0217 - val_loss: 0.0477 - lr: 0.0100
# Epoch 20/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0196
# Epoch 20: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0196 - val_loss: 0.0544 - lr: 0.0100
# Epoch 21/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 21: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0185 - val_loss: 0.0609 - lr: 0.0100
# Epoch 22/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0205
# Epoch 22: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0205 - val_loss: 0.0665 - lr: 0.0100
# Epoch 23/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 23: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0180 - val_loss: 0.0710 - lr: 0.0100
# Epoch 24/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 24: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0158 - val_loss: 0.0741 - lr: 0.0100
# Epoch 25/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 25: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0159 - val_loss: 0.0756 - lr: 0.0100
# Epoch 26/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0151
# Epoch 26: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0151 - val_loss: 0.0757 - lr: 0.0100
# Epoch 27/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 27: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0166 - val_loss: 0.0746 - lr: 0.0100
# Epoch 28/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 28: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0155 - val_loss: 0.0724 - lr: 0.0100
# Epoch 29/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0158
# Epoch 29: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0158 - val_loss: 0.0695 - lr: 0.0100
# Epoch 30/60
# 1/1 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 30: val_loss did not improve from 0.02901
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0141 - val_loss: 0.0658 - lr: 0.0100
# Epoch 30: early stopping

# %%
# performing predictions
train_pred_msft = model.predict(X_train_msft)
# unscaling the predictions
train_pred_msft = scaler_y_msft.inverse_transform(np.array(train_pred_msft).reshape((len(train_pred_msft), 1)))
# printing the predictions
print('Train Predictions MSFT:')
train_pred_msft[0:5]

# performing predictions
test_pred_msft = model.predict(X_test_msft)
# unscaling the predictions
test_pred_msft = scaler_y_msft.inverse_transform(np.array(test_pred_msft).reshape((len(test_pred_msft), 1)))
# printing the predictions
print('Test Predictions MSFT:')
test_pred_msft[0:5]

# calculating the training mean-squared-error
train_loss_msft = model.evaluate(X_train_msft, y_train_msft, batch_size = 1)
# calculating the test mean-squared-error
test_loss_msft = model.evaluate(X_test_msft, y_test_msft, batch_size = 1)
# printing the training and the test mean-squared-errors
print('Train Loss MSFT=', round(train_loss_msft,4))
print('Test Loss MSFT=', round(test_loss_msft,4))
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Train Predictions MSFT:
# 1/1 [==============================] - 0s 23ms/step
# Test Predictions MSFT:
# 101/101 [==============================] - 0s 2ms/step - loss: 0.0219
# 22/22 [==============================] - 0s 2ms/step - loss: 0.1040
# Train Loss MSFT= 0.0219
# Test Loss MSFT= 0.104

# %%
# setting the seed to achieve consistent and less random predictions at each execution
np.random.seed(123)

# setting the model architecture
# Initializing the Neural Network based on LSTM
model = Sequential()
# Adding 1st LSTM layer
model.add(LSTM(units=80, return_sequences=False, input_shape=(len(cols), 1)))
# Adding 2nd LSTM layer
#model.add(LSTM(units=10, return_sequences=False, kernel_regularizer=l2(0.1)))
# Adding Dropout
model.add(Dropout(0.25))
# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# fitting the model using the training dataset
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=15, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
tb = TensorBoard('logs')

# printing the model summary
model.summary()

# fit the model
history_nvda = model.fit(X_train_nvda, y_train_nvda, shuffle=False, epochs=100,
                         callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 80)                26240
#
#  dropout_3 (Dropout)         (None, 80)                0
#
#  dense_3 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 26,321
# Trainable params: 26,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 0.4027
# Epoch 1: val_loss improved from inf to 0.22502, saving model to weights.h5
# 1/1 [==============================] - 3s 3s/step - loss: 0.4027 - val_loss: 0.2250 - lr: 0.0100
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1464
# Epoch 2: val_loss did not improve from 0.22502
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1464 - val_loss: 0.2486 - lr: 0.0100
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 3: val_loss did not improve from 0.22502
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0207 - val_loss: 0.3027 - lr: 0.0100
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0707
# Epoch 4: val_loss did not improve from 0.22502
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0707 - val_loss: 0.2913 - lr: 0.0100
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0802
# Epoch 5: val_loss did not improve from 0.22502
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0802 - val_loss: 0.2447 - lr: 0.0100
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 6: val_loss improved from 0.22502 to 0.20320, saving model to weights.h5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0309 - val_loss: 0.2032 - lr: 0.0100
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 7: val_loss improved from 0.20320 to 0.17688, saving model to weights.h5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0148 - val_loss: 0.1769 - lr: 0.0100
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 8: val_loss improved from 0.17688 to 0.16371, saving model to weights.h5
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0291 - val_loss: 0.1637 - lr: 0.0100
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0473
# Epoch 9: val_loss improved from 0.16371 to 0.15969, saving model to weights.h5
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0473 - val_loss: 0.1597 - lr: 0.0100
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0520
# Epoch 10: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0520 - val_loss: 0.1623 - lr: 0.0100
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0476
# Epoch 11: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0476 - val_loss: 0.1704 - lr: 0.0100
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0327
# Epoch 12: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0327 - val_loss: 0.1832 - lr: 0.0100
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0192
# Epoch 13: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0192 - val_loss: 0.1998 - lr: 0.0100
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 14: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0126 - val_loss: 0.2170 - lr: 0.0100
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0181
# Epoch 15: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0181 - val_loss: 0.2295 - lr: 0.0100
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0262
# Epoch 16: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0262 - val_loss: 0.2312 - lr: 0.0100
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0315
# Epoch 17: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0315 - val_loss: 0.2231 - lr: 0.0100
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0262
# Epoch 18: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0262 - val_loss: 0.2093 - lr: 0.0100
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 19: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0177 - val_loss: 0.1946 - lr: 0.0100
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 20: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0134 - val_loss: 0.1823 - lr: 0.0100
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0148
# Epoch 21: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0148 - val_loss: 0.1732 - lr: 0.0100
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0172
# Epoch 22: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0172 - val_loss: 0.1675 - lr: 0.0100
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0204
# Epoch 23: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0204 - val_loss: 0.1649 - lr: 0.0100
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0239
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 24: val_loss did not improve from 0.15969
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0239 - val_loss: 0.1647 - lr: 0.0100
# Epoch 24: early stopping

# %%
# performing predictions
train_pred_nvda = model.predict(X_train_nvda)
# unscaling the predictions
train_pred_nvda = scaler_y_nvda.inverse_transform(np.array(train_pred_nvda).reshape((len(train_pred_nvda), 1)))
# printing the predictions
print('Train Predictions NVDA:')
train_pred_nvda[0:5]

# performing predictions
test_pred_nvda = model.predict(X_test_nvda)
# unscaling the predictions
test_pred_nvda = scaler_y_nvda.inverse_transform(np.array(test_pred_nvda).reshape((len(test_pred_nvda), 1)))
# printing the predictions
print('Test Predictions NVDA:')
test_pred_nvda[0:5]

# calculating the training mean-squared-error
train_loss_nvda = model.evaluate(X_train_nvda, y_train_nvda, batch_size = 1)
# calculating the test mean-squared-error
test_loss_nvda = model.evaluate(X_test_nvda, y_test_nvda, batch_size = 1)
# printing the training and the test mean-squared-errors
print('Train Loss NVDA=', round(train_loss_nvda,4))
print('Test Loss NVDA=', round(test_loss_nvda,4))
# Out:
# 4/4 [==============================] - 0s 5ms/step
# Train Predictions NVDA:
# 1/1 [==============================] - 0s 35ms/step
# Test Predictions NVDA:
# 101/101 [==============================] - 0s 2ms/step - loss: 0.0486
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4017
# Train Loss NVDA= 0.0486
# Test Loss NVDA= 0.4017

# %%
# setting the seed to achieve consistent and less random predictions at each execution
np.random.seed(123)

# setting the model architecture
# Initializing the Neural Network based on LSTM
model = Sequential()
# Adding 1st LSTM layer
model.add(LSTM(units=70, return_sequences=False, input_shape=(len(cols), 1)))
# Adding 2nd LSTM layer
#model.add(LSTM(units=10, return_sequences=False, kernel_regularizer=l2(0.1)))
# Adding Dropout
model.add(Dropout(0.3))
# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# fitting the model using the training dataset
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=15, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
tb = TensorBoard('logs')

# printing the model summary
model.summary()

# fit the model
history_tsla = model.fit(X_train_tsla, y_train_tsla, shuffle=False, epochs=100,
                         callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 70)                20160
#
#  dropout_4 (Dropout)         (None, 70)                0
#
#  dense_4 (Dense)             (None, 1)                 71
#
# =================================================================
# Total params: 20,231
# Trainable params: 20,231
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 0.3974
# Epoch 1: val_loss improved from inf to 0.06304, saving model to weights.h5
# 1/1 [==============================] - 4s 4s/step - loss: 0.3974 - val_loss: 0.0630 - lr: 0.0100
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 0.1846
# Epoch 2: val_loss improved from 0.06304 to 0.03323, saving model to weights.h5
# 1/1 [==============================] - 0s 101ms/step - loss: 0.1846 - val_loss: 0.0332 - lr: 0.0100
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0612
# Epoch 3: val_loss did not improve from 0.03323
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0612 - val_loss: 0.0473 - lr: 0.0100
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0225
# Epoch 4: val_loss did not improve from 0.03323
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0225 - val_loss: 0.0932 - lr: 0.0100
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0936
# Epoch 5: val_loss did not improve from 0.03323
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0936 - val_loss: 0.0751 - lr: 0.0100
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0703
# Epoch 6: val_loss did not improve from 0.03323
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0703 - val_loss: 0.0421 - lr: 0.0100
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 7: val_loss improved from 0.03323 to 0.02459, saving model to weights.h5
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0271 - val_loss: 0.0246 - lr: 0.0100
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 8: val_loss improved from 0.02459 to 0.02052, saving model to weights.h5
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0210 - val_loss: 0.0205 - lr: 0.0100
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0331
# Epoch 9: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0331 - val_loss: 0.0213 - lr: 0.0100
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 10: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0458 - val_loss: 0.0219 - lr: 0.0100
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0514
# Epoch 11: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0514 - val_loss: 0.0218 - lr: 0.0100
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0379
# Epoch 12: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0379 - val_loss: 0.0221 - lr: 0.0100
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 13: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0307 - val_loss: 0.0248 - lr: 0.0100
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 14: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0233 - val_loss: 0.0308 - lr: 0.0100
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0184
# Epoch 15: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0184 - val_loss: 0.0397 - lr: 0.0100
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 16: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0170 - val_loss: 0.0489 - lr: 0.0100
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 17: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0270 - val_loss: 0.0545 - lr: 0.0100
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0264
# Epoch 18: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0264 - val_loss: 0.0550 - lr: 0.0100
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0269
# Epoch 19: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0269 - val_loss: 0.0508 - lr: 0.0100
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0253
# Epoch 20: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0253 - val_loss: 0.0441 - lr: 0.0100
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0188
# Epoch 21: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0188 - val_loss: 0.0384 - lr: 0.0100
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 22: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0187 - val_loss: 0.0342 - lr: 0.0100
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 23: val_loss did not improve from 0.02052
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0164 - val_loss: 0.0314 - lr: 0.0100
# Epoch 23: early stopping

# %%
# performing predictions
train_pred_tsla = model.predict(X_train_tsla)
# unscaling the predictions
train_pred_tsla = scaler_y_tsla.inverse_transform(np.array(train_pred_tsla).reshape((len(train_pred_tsla), 1)))
# printing the predictions
print('Train Predictions TSLA:')
train_pred_tsla[0:5]

# performing predictions
test_pred_tsla = model.predict(X_test_tsla)
# unscaling the predictions
test_pred_tsla = scaler_y_tsla.inverse_transform(np.array(test_pred_tsla).reshape((len(test_pred_tsla), 1)))
# printing the predictions
print('Test Predictions TSLA:')
test_pred_tsla[0:5]

# calculating the training mean-squared-error
train_loss_tsla = model.evaluate(X_train_tsla, y_train_tsla, batch_size = 1)
# calculating the test mean-squared-error
test_loss_tsla = model.evaluate(X_test_tsla, y_test_tsla, batch_size = 1)
# printing the training and the test mean-squared-errors
print('Train Loss TSLA=', round(train_loss_tsla,4))
print('Test Loss TSLA=', round(test_loss_tsla,4))
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Train Predictions TSLA:
# 1/1 [==============================] - 0s 22ms/step
# Test Predictions TSLA:
# 101/101 [==============================] - 0s 2ms/step - loss: 0.0188
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2987
# Train Loss TSLA= 0.0188
# Test Loss TSLA= 0.2987

# %%
# unscaling the test feature dataset, x_test
X_test_aapl = scaler_x_aapl.inverse_transform(np.array(X_test_aapl).reshape((len(X_test_aapl), len(cols))))
X_test_goog = scaler_x_goog.inverse_transform(np.array(X_test_goog).reshape((len(X_test_goog), len(cols))))
X_test_msft = scaler_x_msft.inverse_transform(np.array(X_test_msft).reshape((len(X_test_msft), len(cols))))
X_test_nvda = scaler_x_nvda.inverse_transform(np.array(X_test_nvda).reshape((len(X_test_nvda), len(cols))))
X_test_tsla = scaler_x_tsla.inverse_transform(np.array(X_test_tsla).reshape((len(X_test_tsla), len(cols))))

# unscaling the test y dataset, y_train
y_train_aapl = scaler_y_aapl.inverse_transform(np.array(y_train_aapl).reshape((len(y_train_aapl), 1)))
y_train_goog = scaler_y_goog.inverse_transform(np.array(y_train_goog).reshape((len(y_train_goog), 1)))
y_train_msft = scaler_y_msft.inverse_transform(np.array(y_train_msft).reshape((len(y_train_msft), 1)))
y_train_nvda = scaler_y_nvda.inverse_transform(np.array(y_train_nvda).reshape((len(y_train_nvda), 1)))
y_train_tsla = scaler_y_tsla.inverse_transform(np.array(y_train_tsla).reshape((len(y_train_tsla), 1)))

# unscaling the test y dataset, y_test
y_test_aapl = scaler_y_aapl.inverse_transform(np.array(y_test_aapl).reshape((len(y_test_aapl), 1)))
y_test_goog = scaler_y_goog.inverse_transform(np.array(y_test_goog).reshape((len(y_test_goog), 1)))
y_test_msft = scaler_y_msft.inverse_transform(np.array(y_test_msft).reshape((len(y_test_msft), 1)))
y_test_nvda = scaler_y_nvda.inverse_transform(np.array(y_test_nvda).reshape((len(y_test_nvda), 1)))
y_test_tsla = scaler_y_tsla.inverse_transform(np.array(y_test_tsla).reshape((len(y_test_tsla), 1)))

# %%
# calculating root mean squared error using sklearn.metrics package
rmse_aapl = np.sqrt(metrics.mean_squared_error(y_test_aapl, test_pred_aapl))
rmse_goog = np.sqrt(metrics.mean_squared_error(y_test_goog, test_pred_goog))
rmse_msft = np.sqrt(metrics.mean_squared_error(y_test_msft, test_pred_msft))
rmse_nvda = np.sqrt(metrics.mean_squared_error(y_test_nvda, test_pred_nvda))
rmse_tsla = np.sqrt(metrics.mean_squared_error(y_test_tsla, test_pred_tsla))
# calculating mean squared error using sklearn.metrics package
mae_aapl = metrics.mean_absolute_error(y_test_aapl, test_pred_aapl)
mae_goog = metrics.mean_absolute_error(y_test_goog, test_pred_goog)
mae_msft = metrics.mean_absolute_error(y_test_msft, test_pred_msft)
mae_nvda = metrics.mean_absolute_error(y_test_nvda, test_pred_nvda)
mae_tsla = metrics.mean_absolute_error(y_test_tsla, test_pred_tsla)
# calculating absolute mean squared error using sklearn.metrics package
mape_aapl = metrics.mean_absolute_percentage_error(y_test_aapl, test_pred_aapl)
mape_goog = metrics.mean_absolute_percentage_error(y_test_goog, test_pred_goog)
mape_msft = metrics.mean_absolute_percentage_error(y_test_msft, test_pred_msft)
mape_nvda = metrics.mean_absolute_percentage_error(y_test_nvda, test_pred_nvda)
mape_tsla = metrics.mean_absolute_percentage_error(y_test_tsla, test_pred_tsla)

# %%
# Create array containing performance metrics
aapl_with_sentiment = np.array([("RMSE_aapl", rmse_aapl),("MAE_aapl", mae_aapl),("MAPE_aapl", mape_aapl)])
goog_with_sentiment = np.array([("RMSE_goog", rmse_goog),("MAE_goog", mae_goog),("MAPE_goog", mape_goog)])
msft_with_sentiment = np.array([("RMSE_msft", rmse_msft),("MAE_msft", mae_msft),("MAPE_msft", mape_msft)])
nvda_with_sentiment = np.array([("RMSE_nvda", rmse_nvda),("MAE_nvda", mae_nvda),("MAPE_nvda", mape_nvda)])
tsla_with_sentiment = np.array([("RMSE_tsla", rmse_tsla),("MAE_tsla", mae_tsla),("MAPE_tsla", mape_tsla)])
# Print the metrics
print(aapl_with_sentiment)
print(goog_with_sentiment)
print(msft_with_sentiment)
print(nvda_with_sentiment)
print(tsla_with_sentiment)
# Out:
# [['RMSE_aapl' '7.403181816406759']
#  ['MAE_aapl' '7.076540245694246']
#  ['MAPE_aapl' '0.03787705646406019']]
# [['RMSE_goog' '3.7224542787867523']
#  ['MAE_goog' '3.452370089244496']
#  ['MAPE_goog' '0.028086001767718152']]
# [['RMSE_msft' '16.502703743486663']
#  ['MAE_msft' '16.301461108309663']
#  ['MAPE_msft' '0.048372224104040386']]
# [['RMSE_nvda' '66.91790144345373']
#  ['MAE_nvda' '66.48729339799364']
#  ['MAPE_nvda' '0.158648943878573']]
# [['RMSE_tsla' '32.98571055816068']
#  ['MAE_tsla' '32.16703731338778']
#  ['MAPE_tsla' '0.12470112160246064']]

# %%
# Plotting the LSTM fit of Apple stock prices without sentiment analysis
aapl_y_train = pd.DataFrame(data = y_train_aapl, index = apple['date'].iloc[0:101,])
aapl_y_test  = pd.DataFrame(data = y_test_aapl, index = apple['date'].iloc[101:,])
aapl_y_train_pred = pd.DataFrame(data = train_pred_aapl, index = apple['date'].iloc[0:101,])
aapl_y_test_pred  = pd.DataFrame(data = test_pred_aapl, index = apple['date'].iloc[101:,])

plt.style.use('seaborn-dark')

plt.plot(aapl_y_train,label = "train, test",color ="green",marker='.')
plt.plot(aapl_y_test,label = "",color ="green",marker='.')
plt.plot(aapl_y_train_pred,color="red",label = "train_pred")
plt.plot(aapl_y_test_pred,color="orange",label = "test_pred")
plt.title("LSTM fit of Apple Stock Market Prices without Sentiment Analysis")
plt.tight_layout()
sns.despine(top=True)
plt.ylabel('', size=15)
plt.xlabel('', size=15)
plt.legend()
plt.grid()
plt.xticks(rotation = 45)
plt.axvline(x = max(aapl_y_train.index),color ="gray", linewidth=2, linestyle='--')
plt.show();

# %%
# Plotting the LSTM fit of Google stock prices without sentiment analysis
goog_y_train = pd.DataFrame(data = y_train_goog, index = google['date'].iloc[0:101,])
goog_y_test  = pd.DataFrame(data = y_test_goog, index = google['date'].iloc[101:,])
goog_y_train_pred = pd.DataFrame(data = train_pred_goog, index = google['date'].iloc[0:101,])
goog_y_test_pred  = pd.DataFrame(data = test_pred_goog, index = google['date'].iloc[101:,])

plt.style.use('seaborn-dark')

plt.plot(goog_y_train,label = "train, test",color ="green",marker='.')
plt.plot(goog_y_test,color ="green",marker='.')
plt.plot(goog_y_train_pred,color="red",label = "train_pred")
plt.plot(goog_y_test_pred,color="orange",label = "test_pred")
plt.title("LSTM fit of Google Stock Market Prices without Sentiment Analysis")
plt.tight_layout()
sns.despine(top=True)
plt.ylabel('', size=15)
plt.xlabel('', size=15)
plt.legend()
plt.grid()
plt.xticks(rotation = 45)
plt.axvline(x = max(goog_y_train.index),color ="gray", linewidth=2, linestyle='--')
plt.show();

# %%
# Plotting the LSTM fit of Microsoft stock prices without sentiment analysis
msft_y_train = pd.DataFrame(data = y_train_msft, index = microsoft['date'].iloc[0:101,])
msft_y_test  = pd.DataFrame(data = y_test_msft, index = microsoft['date'].iloc[101:,])
msft_y_train_pred = pd.DataFrame(data = train_pred_msft, index = microsoft['date'].iloc[0:101,])
msft_y_test_pred  = pd.DataFrame(data = test_pred_msft, index = microsoft['date'].iloc[101:,])

plt.style.use('seaborn-dark')

plt.plot(msft_y_train,label = "train, test",color ="green",marker='.')
plt.plot(msft_y_test,color ="green",marker='.')
plt.plot(msft_y_train_pred,color="red",label = "train_pred")
plt.plot(msft_y_test_pred,color="orange",label = "test_pred")
plt.title("LSTM fit of Microsoft Stock Market Prices without Sentiment Analysis")
plt.tight_layout()
sns.despine(top=True)
plt.ylabel('', size=15)
plt.xlabel('', size=15)
plt.legend()
plt.grid()
plt.xticks(rotation = 45)
plt.axvline(x = max(msft_y_train.index),color ="gray", linewidth=2, linestyle='--')
plt.show();

# %%
# Plotting the LSTM fit of Nvidia stock prices without sentiment analysis
nvda_y_train = pd.DataFrame(data = y_train_nvda, index = nvidia['date'].iloc[0:101,])
nvda_y_test  = pd.DataFrame(data = y_test_nvda, index = nvidia['date'].iloc[101:,])
nvda_y_train_pred = pd.DataFrame(data = train_pred_nvda, index = nvidia['date'].iloc[0:101,])
nvda_y_test_pred  = pd.DataFrame(data = test_pred_nvda, index = nvidia['date'].iloc[101:,])

plt.style.use('seaborn-dark')

plt.plot(nvda_y_train,label = "train, test",color ="green",marker='.')
plt.plot(nvda_y_test,color ="green",marker='.')
plt.plot(nvda_y_train_pred,color="red",label = "train_pred")
plt.plot(nvda_y_test_pred,color="orange",label = "test_pred")
plt.title("LSTM fit of Nvidia Stock Market Prices without Sentiment Analysis")
plt.tight_layout()
sns.despine(top=True)
plt.ylabel('', size=15)
plt.xlabel('', size=15)
plt.legend()
plt.grid()
plt.xticks(rotation = 45)
plt.axvline(x = max(nvda_y_train.index),color ="gray", linewidth=2, linestyle='--')
plt.show();

# %%
# Plotting the LSTM fit of Tesla stock prices without sentiment analysis
tsla_y_train = pd.DataFrame(data = y_train_tsla, index = tesla['date'].iloc[0:101,])
tsla_y_test  = pd.DataFrame(data = y_test_tsla, index = tesla['date'].iloc[101:,])
tsla_y_train_pred = pd.DataFrame(data = train_pred_tsla, index = tesla['date'].iloc[0:101,])
tsla_y_test_pred  = pd.DataFrame(data = test_pred_tsla, index = tesla['date'].iloc[101:,])

plt.style.use('seaborn-dark')

plt.plot(tsla_y_train,label = "train, test",color ="green",marker='.')
plt.plot(tsla_y_test,color ="green",marker='.')
plt.plot(tsla_y_train_pred,color="red",label = "train_pred")
plt.plot(tsla_y_test_pred,color="orange",label = "test_pred")
plt.title("LSTM fit of Tesla Stock Market Prices without Sentiment Analysis")
plt.tight_layout()
sns.despine(top=True)
plt.ylabel('', size=15)
plt.xlabel('', size=15)
plt.legend()
plt.grid()
plt.xticks(rotation = 45)
plt.axvline(x = max(tsla_y_train.index),color ="gray", linewidth=2, linestyle='--')
plt.show();
